# %%
import numpy as np
import matplotlib.pyplot as plt
import thermodynamics as thermo
import ODESolve_slow as ODE

# %%
def f(a,y,p):
   
    T, p, P, s = y  # y is an array of length 4
    
    der = np.zeros(4) # der is an array of length 4 
    der[0] = -T/a
    der[1] = thermo.dpdT(T,0.511,2)*der[0]
    der[2] = thermo.dPdT(T,0.511,2)*der[0]
    der[3] = thermo.dsdT(T,0.511,2)*der[0]
    
    return der

a0=0.1
y0=np.array([10,(7*np.pi**2)/120*10**4,(7*np.pi**2)/360*10**4,(7*np.pi**2)/90*10**3])
dx0=0.001
p=None


N_step = 1000
dN = 2
x_final = 100


print(f(a0,y0,p)) 

a, y, dx, done = ODE.ODEOneRun(a0, y0, dx0, p, N_step, dN, x_final)
print(done)
# Out:
# [-1.00000000e+02 -2.30269005e+05 -7.67418340e+04 -2.30269005e+04]
# True

# %%
plt.figure()
plt.semilogx(y[:,0],y[:,1])
plt.xlim(10,0.01)

T=np.logspace(-2,1,50)
y=np.zeros(len(T))
for i in range(len(T)):
    y[i]=thermo.p(T[i],0.511,2)
plt.semilogx(T,y)
plt.xlim(10,0.01)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[106], line 2
#       1 plt.figure()
# ----> 2 plt.semilogx(y[:,0],y[:,1])
#       3 plt.xlim(10,0.01)
#       5 T=np.logspace(-2,1,50)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
plt.figure()
plt.semilogx(y[:,0],y[:,2])
plt.xlim(10,.01)
# Out:
# (10, 0.01)

# %%
plt.figure()
plt.semilogx(y[:,0],y[:,3])
plt.xlim(10,.01)
# Out:
# (10, 0.01)

# %%
plt.figure()
plt.semilogx(a,y[:,0])
plt.xlim(10,.01)
# Out:
# (10, 0.01)
