# %%
nB =

# %%
MeVtoT9 = 11604525006.1657/10**9

# %%
def void_rate_all(f, T9, struct relicparam* paramrelic, struct errorparam* paramerror)
#* calculates the nuclear forward rates f[] of the nuclear reactions given
#* below at the temperature T9 */
#* err=0: central values; err=1: high values; err=2: low values; err=4:
#* random gaussian error; err=3: error only for process number (errnumber) */
#{	
    double ferrlow[NNUCREACMAX+1],ferrhigh[NNUCREACMAX+1];
    int ie;

    if(paramrelic->err>0) for(ie=12;ie<=NNUCREAC;ie++)
    {
        ferrhigh[ie]=9.;
        ferrlow[ie]=-0.9;
     }

#if defined(_OPENMP) && NMAX>30	
#pragma omp parallel for
#endif
	for(ie=12;ie<=(int)min(100,NNUCREAC);ie++)
	{
		switch(ie)
		{
			case 12:
			{
				#* H + n -> g + H2 */   // Ando et al. 2006 (updated from Serpico et al. 2004)
				if(T9<=1.5)
				{
					f[12]=44216.*(1+3.75191*T9+1.92934*T9*T9+0.746503*T9*T9*T9+0.0197023*(T9**4)+3.00491e-6*(T9**5))/
							(1+5.4678*T9+5.62395*T9*T9+0.489312*T9*T9*T9+0.00747806*(T9**4));
				}
				else
				{
					f[12]=(1.-np.sqrt(T9)*0.8504+T9*0.4895-(T9**(3/2))*0.09623+T9*0.008471*T9-T9*2.8e-4*(T9**(3/2)))*47420.;
				}

				if(paramrelic->err>0)
				{
					if (T9<=1.5)
					{
						ferrlow[12]=-0.00449213*(1.+3.08947*T9+0.13277*T9*T9+1.66472*T9*T9*T9)/
								(1.+2.75245*T9+1.40958*T9*T9+0.8791*T9*T9*T9);
					else ferrlow[12]=-0.078;

					ferrhigh[12]=-ferrlow[12];
				}
				break;
			}
# Out:
#   Cell In[15], line 1
#     def void_rate_all(double f[], double T9, struct relicparam* paramrelic, struct errorparam* paramerror)
#                              ^
# SyntaxError: invalid syntax

# %%
def pngd(T):
    T9 = T*MeVtoT9
    if T9<=1.5:
        F=
    else:
        F = 
    return F*
