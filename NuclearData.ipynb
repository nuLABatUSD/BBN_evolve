# %%
import numpy as np

# %%
data = np.loadtxt("reaction_rates.csv",delimiter = ',')

# %%
print(data.shape)
# Out:
# (60, 4)

# %%
print(data[:,0])
# Out:
# [1.00e+01 9.00e+00 8.00e+00 7.00e+00 6.00e+00 5.00e+00 4.00e+00 3.50e+00
#  3.00e+00 2.50e+00 2.00e+00 1.75e+00 1.50e+00 1.25e+00 1.00e+00 9.00e-01
#  8.00e-01 7.00e-01 6.00e-01 5.00e-01 4.50e-01 4.00e-01 3.50e-01 3.00e-01
#  2.50e-01 2.00e-01 1.80e-01 1.60e-01 1.50e-01 1.40e-01 1.30e-01 1.20e-01
#  1.10e-01 1.00e-01 9.00e-02 8.00e-02 7.00e-02 6.00e-02 5.00e-02 4.00e-02
#  3.00e-02 2.50e-02 2.00e-02 1.80e-02 1.60e-02 1.50e-02 1.40e-02 1.30e-02
#  1.20e-02 1.10e-02 1.00e-02 9.00e-03 8.00e-03 7.00e-03 6.00e-03 5.00e-03
#  4.00e-03 3.00e-03 2.00e-03 1.00e-03]

# %%
np.save("nuclear_data", np.transpose(data))
