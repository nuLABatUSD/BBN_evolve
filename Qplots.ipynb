# %%
import numpy as np

# %%
Q0_data=np.load("Q0.npz")

Q1_data=np.load("Q1.npz")

Q2_data=np.load("Q2.npz")

Q3_data=np.load("Q3.npz")

# %%
print(Q0_data.files)
# Out:
# ['a_total', 'y_total']

# %%
Q0_a = Q0_data['a_total']
Q0_y = Q0_data['y_total']

# %%
Q1_a = Q1_data['a_total']
Q1_y = Q1_data['y_total']

# %%
Q2_a = Q2_data['a_total']
Q2_y = Q2_data['y_total']

# %%
Q3_a = Q3_data['a_total']
Q3_y = Q3_data['y_total']
