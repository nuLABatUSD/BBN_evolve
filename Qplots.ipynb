# %%
import ODESolve_slow as ODE
import matplotlib.pyplot as plt
from constants import mN
import numpy as np
import thermodynamics as thermo
from constants import me, mpl, zeta3, hbar, MeVtoT9, cmgstoMeV
import weakrates as weak
import expansion as ex
import nseabundance as nse
import derivatives as der
import xy_reactions as xy
import xgamma_reactions as xg

# %%
Q0_data=np.load("Q0.npz")

Q3_data=np.load("Q3.npz")

Q6_data=np.load("Q6.npz")

# %%
print(Q0_data.files)
# Out:
# ['a_total', 'y_total']

# %%
Q0_a = Q0_data['a_total']
Q0_y = Q0_data['y_total']

# %%
Q6_a = Q6_data['a_total']
Q6_y = Q6_data['y_total']

# %%
Q3_a = Q3_data['a_total']
Q3_y = Q3_data['y_total']

# %%
plt.figure()
plt.loglog(Q0_y[:,1] * hbar, Q0_y[:,3+nse.H2_INDEX], color = "red")
plt.loglog(Q3_y[:,1] * hbar, Q3_y[:,3+nse.H2_INDEX], color = "green")
plt.loglog(Q6_y[:,1] * hbar, Q6_y[:,3+nse.H2_INDEX], color = "blue")
plt.xlim(10, 1e4)
plt.ylim(1e-8, 1e-2)

plt.show()

# %%
plt.figure()
plt.loglog(Q0_y[:,1] * hbar, Q0_y[:,3+nse.H3_INDEX], color = "red")
plt.loglog(Q3_y[:,1] * hbar, Q3_y[:,3+nse.H3_INDEX], color = "green")
plt.loglog(Q6_y[:,1] * hbar, Q6_y[:,3+nse.H3_INDEX], color = "blue")
plt.xlim(10, 1e4)
plt.ylim(1e-8, 1e-2)

plt.show()

# %%
plt.figure()
plt.loglog(Q0_y[:,1] * hbar, Q0_y[:,3+nse.HE3_INDEX], color = "red")
plt.loglog(Q3_y[:,1] * hbar, Q3_y[:,3+nse.HE3_INDEX],color = "green")
plt.loglog(Q6_y[:,1] * hbar, Q6_y[:,3+nse.HE3_INDEX], color = "blue")
plt.xlim(10, 1e4)
plt.ylim(1e-8, 1e-2)

plt.show()

# %%
plt.figure()
plt.loglog(Q0_y[:,1] * hbar, Q0_y[:,3+nse.HE4_INDEX], color = "red")
plt.loglog(Q3_y[:,1] * hbar, Q3_y[:,3+nse.HE4_INDEX], color = "green")
plt.loglog(Q6_y[:,1] * hbar, Q6_y[:,3+nse.HE4_INDEX], color = "blue")
plt.xlim(10, 1e4)
plt.ylim(1e-8, 1e-2)

plt.show()

# %%
plt.figure()
plt.loglog(Q0_y[:,1] * hbar, Q0_y[:,2], color = "red")
plt.loglog(Q3_y[:,1] * hbar, Q3_y[:,2], color = "green")
plt.loglog(Q6_y[:,1] * hbar, Q6_y[:,2], color = "blue")

plt.show()
